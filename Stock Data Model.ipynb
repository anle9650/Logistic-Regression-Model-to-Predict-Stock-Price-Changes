# %%
import pandas as pd
import numpy as np
from numpy import genfromtxt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import confusion_matrix

# %%
# load the data

X_train_std = pd.read_csv("data/X_train_std.csv")
y_train_encoded = genfromtxt('data/y_train_encoded.csv', delimiter=',')

X_test_std = pd.read_csv("data/X_test_std.csv")
y_test_encoded = genfromtxt('data/y_test_encoded.csv', delimiter=',')

judge_data = pd.read_csv("data/stock_judge_data.csv")
judge_data_std = pd.read_csv("data/judge_data_std.csv")

# %%
X_train_std.head()
# Out:
#         roa       ocf  roa_change  accruals  change_leverage  \
# 0  0.054219 -0.030252   -0.076924 -0.030380        -0.016244
# 1  0.066049 -0.030197    0.168624 -0.030325        -0.016381
# 2  0.055584 -0.030052   -0.009956 -0.030180        -0.016324
# 3  0.050124 -0.025236   -0.013756 -0.025364        -0.033483
# 4  0.119741 -0.030018   -0.020880 -0.030146        -0.016244
#
#    change_curr_ratio  change_shares  change_gross_margin  \
# 0      -5.994929e-03      -0.021087            -0.006206
# 1      -9.004430e-03      -0.019400            -0.000660
# 2       2.641278e-18      -0.019268            -0.000352
# 3       2.641278e-18      -0.021109            -0.000352
# 4       3.007150e-02      -0.021068            -0.002200
#
#    change_asset_turnover
# 0              -0.137630
# 1               2.307142
# 2               0.049789
# 3               0.037294
# 4              -0.200102

# %%
# drop the symbols from the judgement data
judge_data_std.drop(columns='symbol', inplace=True)

# %%
# fit logistic regression on the training data
model = LogisticRegression()
model.fit(X_train_std, y_train_encoded)
# Out:
# LogisticRegression()

# %%
# get feature coefficients
features = ["roa", "ocf", "roa_change", "accruals", "change_leverage", "change_curr_ratio", "change_shares",
            "change_gross_margin", "change_asset_turnover"]
coef = model.coef_
feat_coef = [(features[i], coef[0][i]) for i in range(len(features))]

# %%
# sort features by absolute value of coefficients in descending order
feat_coef_sorted = sorted(feat_coef, key=lambda row: np.abs(row[1]), reverse=True)
print("Feature coefficients in descending order:\n")
for entry in feat_coef_sorted:
    print(entry[0] + ": " + str(entry[1]))
# Out:
# Feature coefficients in descending order:
#
# roa: 0.2553430333440398
# change_shares: -0.09505043595395439
# change_asset_turnover: -0.050392548797710546
# change_curr_ratio: -0.03661885016248814
# accruals: -0.014281451069728102
# ocf: -0.013359691558674147
# roa_change: 0.0048016457767721
# change_leverage: -0.0011928556142102918
# change_gross_margin: 0.0007779274915240857

# %%
# predict the testing data with the model
test_pred = model.predict(X_test_std)

# %%
# accuracy
accuracy = accuracy_score(y_test_encoded, test_pred)
print("Accuracy: " + str(accuracy))

# precision
precision = precision_score(y_test_encoded, test_pred)
print("Precision: " + str(precision))

# npv
tn, fp, fn, tp = confusion_matrix(y_test_encoded, test_pred).ravel()
npv = tn / (tn + fn)
print("NPV: " + str(npv))

# recall
recall = recall_score(y_test_encoded, test_pred)
print("Recall: " + str(recall))

# F1
f1 = f1_score(y_test_encoded, test_pred)
print("F1: " + str(f1))

# MCC
mcc = matthews_corrcoef(y_test_encoded, test_pred)
print("MCC: " + str(mcc))
# Out:
# Accuracy: 0.5580379430853719
# Precision: 0.5575749872902898
# NPV: 0.5833333333333334
# Recall: 0.9865077580391275
# F1: 0.7124644742184327
# MCC: 0.037669228779321474

# %%
# get the positive test prediction probabilities
test_prob = model.predict_proba(X_test_std)[:, 1]

# %%
# construct a dataframe of actual, predicted, and probability values for the test data
test_pred_prob = pd.DataFrame({'actual': y_test_encoded, 'predicted': test_pred, 'probability': test_prob})
test_pred_prob
# Out:
#       actual  predicted  probability
# 0        1.0        1.0     0.553848
# 1        1.0        1.0     0.543151
# 2        0.0        1.0     0.553169
# 3        0.0        1.0     0.534829
# 4        1.0        1.0     0.553479
# ...      ...        ...          ...
# 8007     0.0        1.0     0.529193
# 8008     0.0        1.0     0.552917
# 8009     1.0        1.0     0.624332
# 8010     0.0        1.0     0.558054
# 8011     1.0        1.0     0.555461
#
# [8012 rows x 3 columns]

# %%
# predict the judgement data with the model
judge_pred = model.predict_proba(judge_data_std)

# %%
# add the predictions to judgement data
judge_data['probability'] = judge_pred[:, 1]

# %%
# sort the judgement data in descending order
judge_data.sort_values(by=['probability'], ascending=False, inplace=True, ignore_index=True)

# %%
# show the top stock predictions (most likely to increase in value over the next year)
judge_data.head(10)
# Out:
#   symbol    roa          ocf  roa_change      accruals  change_leverage  \
# 0   AMRK  0.003    -544000.0       0.008 -5.440000e+05         32198000
# 1    HQI -0.007    2784031.0      -0.049  2.784031e+06                0
# 2   HFFG  0.020    8277366.0      -0.077  8.277366e+06         72927014
# 3   SIGA -0.036   -2322143.0      -2.808 -2.322143e+06          4497269
# 4     AM -0.054 -398493000.0      -1.477 -3.984930e+08       2892249000
# 5    FVE -0.017  -20274000.0       0.163 -2.027400e+07        -29280000
# 6    SKY -0.086  -37890000.0      -0.086 -3.789000e+07         83339000
# 7   INTZ  0.705    4507000.0      -0.116  4.506999e+06          -274000
# 8     TA  0.010   65284000.0       0.086  6.528400e+07       1993051000
# 9   IDEX -0.665  -63478589.0      -0.468 -6.347859e+07         -3167905
#
#    change_curr_ratio  change_shares  change_gross_margin  \
# 0              0.174            0.0                0.003
# 1             -1.454      8907141.0                0.744
# 2             -0.387     29977610.0               -0.007
# 3             -8.735       330994.0                0.133
# 4              0.275    297848678.0               -0.247
# 5              0.272        70377.0               -0.014
# 6             -0.486     48265947.0                0.087
# 7              1.459       237794.0               -0.018
# 8             -1.154       227069.0                0.164
# 9             -1.303     27964086.0                0.959
#
#    change_asset_turnover  probability
# 0                 -5.304     0.789952
# 1                 -3.828     0.733470
# 2                 -3.053     0.699934
# 3                 -3.003     0.697323
# 4                 -3.194     0.689928
# 5                 -2.174     0.660536
# 6                 -2.198     0.657203
# 7                 -1.706     0.657044
# 8                 -2.054     0.655674
# 9                 -2.416     0.653381

# %%
# show the bottom stock predictions (most likely to decrease in value over the next year)
judge_data.tail(10)
# Out:
#      symbol     roa           ocf  roa_change      accruals  change_leverage  \
# 4423   TALK  -3.725 -3.338170e+05       0.900 -3.338133e+05           442640
# 4424   KULR  -4.044 -2.081588e+06      -2.826 -2.081584e+06                0
# 4425   GMBL  -8.405 -3.305193e+06      -5.463 -3.305185e+06           290720
# 4426   VERB -10.378 -7.792000e+06       0.000 -7.791990e+06                0
# 4427    TLK   0.132  3.846200e+13      -0.041  3.846200e+13    8610000000000
# 4428   HGEN -11.991 -8.944000e+06      -5.585 -8.943988e+06          2992000
# 4429   BTCY -20.582 -8.592065e+06     -14.208 -8.592044e+06           867699
# 4430   ENIA   0.056  3.917446e+09       0.005  3.917446e+09        116587000
# 4431   ENIC   0.039  7.101980e+11      -0.016  7.101980e+11    -186397316000
# 4432   ZIVO -70.261 -8.352350e+06     -56.378 -8.352280e+06        -12874278
#
#       change_curr_ratio  change_shares  change_gross_margin  \
# 4423             -0.042   1.673534e+09               -2.055
# 4424             -1.745   1.526105e+06                0.401
# 4425                NaN   6.623500e+04                  NaN
# 4426              0.000   0.000000e+00                0.000
# 4427             -0.123  -1.737780e+09               -0.051
# 4428             -0.124   4.191900e+06                  NaN
# 4429             -0.983   5.364952e+06                  NaN
# 4430              0.315   1.863367e+10                0.021
# 4431              0.159   2.007378e+10                0.013
# 4432              0.024   2.221623e+08                  NaN
#
#       change_asset_turnover  probability
# 4423                  0.586     0.321465
# 4424                  2.385     0.317514
# 4425                  0.000     0.314730
# 4426                  0.000     0.270000
# 4427                 -0.032     0.268866
# 4428                  0.000     0.232237
# 4429                  0.358     0.092073
# 4430                 -0.053     0.013792
# 4431                 -0.012     0.009403
# 4432                  0.000     0.000293

# %%
# save judgement predictions
judge_data.to_csv('data/judge_data_pred.csv', index=False)
